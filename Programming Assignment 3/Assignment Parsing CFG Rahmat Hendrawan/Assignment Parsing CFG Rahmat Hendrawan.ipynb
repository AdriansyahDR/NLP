# %% [markdown]
# #Latihan CFG

# %% [markdown]
# #Create Rules Manually
# Berikut adalah contoh production rules yang dibuat manual dalam format string biasa.
# ```
# cfg_rules = """
# S -> NP VP
# NP -> Det N | PropN
# Det -> PosPro | Art
# VP -> Vt NP
# Art -> 'the' | 'a'
# PropN -> 'Alice'
# N -> 'duck' | 'telescope' | 'park'
# Vt -> 'saw'
# PosPro -> 'my' | 'her'
# """
# ```
#
# #Create CFG from String
# Selanjutnya buat objek grammar CFG dari string di atas. Akan terbentuk objek grammar dengan 15 productions.
# ```
# cfg = nltk.CFG.fromstring(cfg_rules)
# print(cfg)
# ```
# #Parsing
# Dari grammar tersebut, kita coba untuk mendapatkan parse tree dari sebuah kalimat. Tampilkan hasil parse tree.
# ```
# from nltk.parse.chart import BottomUpChartParser
# parser = BottomUpChartParser(cfg)
# sentence = 'the duck saw Alice'.split()
# parsed = list(parser.parse(sentence))
# print(parsed[0])
# parsed[0].draw()
# ```
#
# #Extract Production Rules From Corpus
# Sebagai alternatif cara membuat grammar selain manual, kita bisa mengekstrak rules dari corpus yang telah dianotasi. Corpus berbahasa Inggris yang terkenal misalnya penn treebank. Salah satu corpus treebank berbahasa indonesia bisa dilihat di https://github.com/famrashel/idn-treebank.
# ```
# from nltk import Tree
#
# parsed_string = "(S      (NP-SBJ-1    (NN      Kisah) (NP      (NN      pendiri) (NNP      Facebook))) (VP      (VB      dibuat) (S  (NP-SBJ  *-1) (NP-PRD  (NN      komik)))))"
# t = Tree.fromstring(parsed_string)
# print(t.productions())
# ```
#
# #Create CFG from Production Rules
# Setelah mendapatkan list production rules dari corpus, selanjutnya kita bisa membuat grammar CFG. Grammar ini selanjutnya bisa dipakai untuk melakukan parsing pada data testing atau data baru.
# ```
# from nltk.grammar import CFG, Nonterminal
# grammar = CFG(Nonterminal('S'), t.productions())
# print(grammar)
# ```
#
# #Menambahkan Production Rules ke existing grammar
# Jika suatu saat corpus kita bertambah, maka kita bisa menambahkan production rules baru ke existing grammar.
# ```
# from nltk.grammar import Nonterminal, Production
#
# #Cara membuat objek Nonterminal
# lhs = Nonterminal('S')
# rhs1 = Nonterminal('A')
# rhs2 = Nonterminal('B')
# #Untuk Objek terminal cukup string saja
# rhs3 = "saya"
# #Buat objek Production
# newprod = Production(lhs,[rhs1,rhs2,rhs3])
#
# #Tambahkan ke existing grammar
# grammar.productions().append(newprod)
# print(grammar)
# ```
#
# #Tugas
# 1. Ekstraklah Production Rules dari minimal 100 kalimat pertama (tergantung kemampuan perangkat) dari Corpus https://github.com/famrashel/idn-treebank/blob/master/Indonesian_Treebank.bracket. Anda mungkin perlu menghubungkan gdrive ke colab. Cek tutorial ini :  https://www.marktechpost.com/2019/06/07/how-to-connect-google-colab-with-google-drive/
#
# 2. Print top-10 Rules yang paling sering muncul. Hint gunakan collection.Counter.
#
# 3. Buatlah grammar CFG dari production rules yang telah diekstrak.
# 4. Lakukan Parsing terhadap kalimat berikut ini:
# ```
# Binatang ini tidak bisa dibunuh karena masyarakat India menganggap mereka suci .
# ```
#
# 5. Print top-50 lexicon atau terminal symbol.
#
# dari contoh ini: (S  (PP  (IN	  (Selama)) (NP  (CD	  (bertahun-tahun)))) (NP-SBJ  (NN	  (monyet))) (VP  (VB	  (mengganggu)) (NP  (NN	  (warga)) (NNP	  (Delhi)))) (Z	  (.)))
# yang dimaksuk lexicon adalah : Selama, bertahun-tahun, monyet, mengganggu, warga, Delhi, .
#
# 6. Buatlah 5 kalimat baru dari top-50 lexicon, lalu parsing kalimat tersebut.

# %% [markdown]
# # JAWABAN

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#contoh path
path = '/content/gdrive/My Drive/tugas nlp/Indonesian_Treebank.bracket'

# %%
import nltk
from nltk import Tree
import re
from collections import Counter
from nltk.grammar import CFG, Nonterminal
from nltk.parse.chart import BottomUpChartParser

# %% [markdown]
# ###Ekstrak Production Rules

# %%
#here
with open(path,'r') as file:
  data = file.read().splitlines()
t = []
tleaf = []
for i in range (35):
  data[i] = re.sub(r'\(([a-zA-Z0-9-*.:,"]+)\)',r'\1',data[i])  
  rule = Tree.fromstring(data[i].upper())
  t.extend(rule.productions())
  tleaf.extend(t.leaves())

# %%
t
# Out:
# [NP -> NN SBAR,
#  NN -> 'KERA',
#  SBAR -> SC S,
#  SC -> 'UNTUK',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> 'AMANKAN',
#  NP -> NN,
#  NN -> PESTA,
#  PESTA -> 'OLAHRAGA',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> NNP NNP NNP,
#  NNP -> 'PEMERINTAH',
#  NNP -> 'KOTA',
#  NNP -> 'DELHI',
#  VP -> VB NP SBAR,
#  VB -> 'MENGERAHKAN',
#  NP -> NN,
#  NN -> 'MONYET',
#  SBAR -> SC S,
#  SC -> 'UNTUK',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP PP,
#  VB -> 'MENGUSIR',
#  NP -> NP SBAR,
#  NP -> NN JJ,
#  NN -> 'MONYET-MONYET',
#  JJ -> 'LAIN',
#  SBAR -> SC S,
#  SC -> 'YANG',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB ADJP,
#  VB -> 'BERBADAN',
#  ADJP -> RB JJ,
#  RB -> 'LEBIH',
#  JJ -> 'KECIL',
#  PP -> IN NP,
#  IN -> 'DARI',
#  NP -> NN NP,
#  NN -> 'ARENA',
#  NP -> NNP NNP,
#  NNP -> PESTA,
#  PESTA -> 'OLAHRAGA',
#  NNP -> 'PERSEMAKMURAN',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> CD NN,
#  CD -> 'BEBERAPA',
#  NN -> 'LAPORAN',
#  VP -> VB SBAR,
#  VB -> 'MENYEBUTKAN',
#  SBAR -> '0' S,
#  S -> NP-SBJ-1 VP,
#  NP-SBJ-1 -> QP NN,
#  QP -> RB CD,
#  RB -> 'SETIDAKNYA',
#  CD -> '10',
#  NN -> 'MONYET',
#  VP -> VB NP PP,
#  VB -> 'DITEMPATKAN',
#  NP -> '*-1',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NN NP,
#  NN -> 'LUAR',
#  NP -> NP PP,
#  NP -> NN NP,
#  NN -> 'ARENA',
#  NP -> NN CC NN,
#  NN -> 'LOMBA',
#  CC -> 'DAN',
#  NN -> 'PERTANDINGAN',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NNP NNP,
#  NNP -> 'IBUKOTA',
#  NNP -> 'INDIA',
#  Z -> '.',
#  S -> NP-SBJ-1 VP Z,
#  NP-SBJ-1 -> NNP NNP,
#  NNP -> 'PEMKOT',
#  NNP -> 'DELHI',
#  VP -> VP CC VP,
#  VP -> VB NP,
#  VB -> 'MEMILIKI',
#  NP -> CD NN,
#  CD -> '28',
#  NN -> 'MONYET',
#  CC -> 'DAN',
#  VP -> VB S,
#  VB -> 'BERENCANA',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*-1',
#  VP -> VB NP PP,
#  VB -> 'MENDATANGKAN',
#  NP -> CD NN NN,
#  CD -> '10',
#  NN -> 'MONYET',
#  NN -> 'SEJENIS',
#  PP -> IN NP,
#  IN -> 'DARI',
#  NP -> NNP NNP,
#  NNP -> NEGARA,
#  NEGARA -> 'BAGIAN',
#  NNP -> 'RAJASTHAN',
#  Z -> '.',
#  S -> S Z S CC S Z,
#  S -> NP-SBJ VP,
#  NP-SBJ -> NP PP,
#  NP -> NN NN,
#  NN -> 'JUMLAH',
#  NN -> 'MONYET',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NNP NNP,
#  NNP -> 'IBUKOTA',
#  NNP -> 'INDIA',
#  VP -> VB NP,
#  VB -> 'MENCAPAI',
#  NP -> CD,
#  CD -> 'RIBUAN',
#  Z -> ',',
#  S -> NP-SBJ VP,
#  NP-SBJ -> NN,
#  NN -> SEBAGIAN,
#  SEBAGIAN -> 'BESAR',
#  VP -> VB PP,
#  VB -> 'BERADA',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NN NN,
#  NN -> 'KANTOR-KANTOR',
#  NN -> 'PEMERINTAH',
#  CC -> 'DAN',
#  S -> NP-SBJ-1 VP,
#  NP-SBJ-1 -> NN PR,
#  NN -> 'HEWAN',
#  PR -> 'INI',
#  VP -> VB S,
#  VB -> 'DIANGGAP',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*-1',
#  VP -> VB NP,
#  VB -> 'MENGGANGGU',
#  NP -> NN JJ,
#  NN -> 'KETERTIBAN',
#  JJ -> 'UMUM',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> NP SBAR,
#  NP -> NN NN,
#  NN -> 'JENIS',
#  NN -> 'MONYET',
#  SBAR -> SC S,
#  SC -> 'YANG',
#  S -> NP-SBJ-1 VP,
#  NP-SBJ-1 -> '*',
#  VP -> VB NP NP-LGS,
#  VB -> 'DIKERAHKAN',
#  NP -> '*-1',
#  NP-LGS -> NN,
#  NN -> 'PEMKOT',
#  VP -> VP Z VP Z CC VP,
#  VP -> VB ADJP,
#  VB -> 'BERBADAN',
#  ADJP -> JJ,
#  JJ -> 'BESAR',
#  Z -> ',',
#  VP -> VB ADJP,
#  VB -> 'BEREKOR',
#  ADJP -> JJ,
#  JJ -> 'PANJANG',
#  Z -> ',',
#  CC -> 'DAN',
#  VP -> VB NP,
#  VB -> 'MEMILIKI',
#  NP -> NN SBAR,
#  NN -> 'WAJAH',
#  SBAR -> '0' S,
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB ADJP,
#  VB -> 'BERWARNA',
#  ADJP -> JJ,
#  JJ -> 'HITAM',
#  Z -> '.',
#  S -> S CC S Z,
#  S -> NP-SBJ-1 VP,
#  NP-SBJ-1 -> NN PR,
#  NN -> 'MONYET',
#  PR -> 'INI',
#  VP -> VB NP PP,
#  VB -> 'DIIKAT',
#  NP -> '*-1',
#  PP -> IN NP,
#  IN -> 'DENGAN',
#  NP -> NN JJ,
#  NN -> 'TALI',
#  JJ -> 'PANJANG',
#  CC -> 'DAN',
#  S -> NP-SBJ VP,
#  NP-SBJ -> NN SBAR,
#  NN -> 'PELATIH',
#  SBAR -> SC S,
#  SC -> 'YANG',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> 'MENGAWASI',
#  NP -> PRP,
#  PRP -> 'MEREKA',
#  VP -> MD VP,
#  MD -> 'AKAN',
#  VP -> VB NP SBAR,
#  VB -> 'MELEPAS',
#  NP -> NN,
#  NN -> 'TALI',
#  SBAR -> SC S,
#  SC -> 'BEGITU',
#  S -> NP-SBJ VP,
#  NP-SBJ -> NN JJ JJ,
#  NN -> 'MONYET-MONYET',
#  JJ -> 'KECIL',
#  JJ -> 'LAIN',
#  VP -> VB,
#  VB -> 'MENDEKAT',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> NNP NNP,
#  NNP -> KANTOR,
#  KANTOR -> 'BERITA',
#  NNP -> 'AFP',
#  VP -> VB SBAR,
#  VB -> 'MELAPORKAN',
#  SBAR -> '0' S,
#  S -> NP-SBJ VP,
#  NP-SBJ -> NN NP,
#  NN -> 'STADION',
#  NP -> NP CC NP,
#  NP -> NN,
#  NN -> 'TINJU',
#  CC -> 'DAN',
#  NP -> FW,
#  FW -> 'HOCKEY',
#  VP -> VB NP SBAR,
#  VB -> 'MENDAPATKAN',
#  NP -> NN JJ,
#  NN -> 'PERHATIAN',
#  JJ -> 'KHUSUS',
#  SBAR -> SC S,
#  SC -> 'KARENA',
#  S -> NP-SBJ-1 ADVP VP,
#  NP-SBJ-1 -> '*',
#  ADVP -> RB,
#  RB -> 'SERING',
#  VP -> VB NP NP-LGS,
#  VB -> 'DISERBU',
#  NP -> '*-1',
#  NP-LGS -> NN,
#  NN -> 'MONYET',
#  Z -> '.',
#  S -> NP-SBJ-1 VP,
#  NP-SBJ-1 -> NN JJ,
#  NN -> 'MONYET',
#  JJ -> 'BESAR',
#  VP -> MD VP,
#  MD -> 'AKAN',
#  VP -> VB NP PP SBAR,
#  VB -> 'DIKERAHKAN',
#  NP -> '*-1',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> CD NN,
#  CD -> 'DUA',
#  NN -> 'STADION',
#  SBAR -> SC S,
#  SC -> 'UNTUK',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> 'MENGUSIR',
#  NP -> NN NP,
#  NN -> 'SERBUAN',
#  NP -> NN JJ,
#  NN -> 'MONYET',
#  JJ -> 'KECIL',
#  SINV -> Z S-TPC-1 Z Z VP NP-SBJ PP Z,
#  Z -> '"',
#  S-TPC-1 -> NP-SBJ-2 VP,
#  NP-SBJ-2 -> NN JJ,
#  NN -> 'MONYET',
#  JJ -> 'BESAR',
#  VP -> MD VP,
#  MD -> 'AKAN',
#  VP -> VB NP PP SBAR,
#  VB -> 'DIKERAHKAN',
#  NP -> '*-2',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> CD NN PR,
#  CD -> 'DUA',
#  NN -> 'STADION',
#  PR -> 'TERSEBUT',
#  SBAR -> SC S,
#  SC -> 'UNTUK',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> 'MENGUSIR',
#  NP -> NN NP,
#  NN -> 'SERBUAN',
#  NP -> NN JJ,
#  NN -> 'MONYET',
#  JJ -> 'KECIL',
#  Z -> ',',
#  Z -> '"',
#  VP -> VB S,
#  VB -> 'KATA',
#  S -> '*T*-1',
#  NP-SBJ -> NP Z NP,
#  NP -> NNP NNP,
#  NNP -> 'DEVENDER',
#  NNP -> 'PRASAD',
#  Z -> ',',
#  NP -> NN NP,
#  NN -> 'PEJABAT',
#  NP -> NNP NNP NNP,
#  NNP -> 'PEMERINTAH',
#  NNP -> 'KOTA',
#  NNP -> 'DELHI',
#  PP -> IN NP,
#  IN -> 'KEPADA',
#  NP -> NNP NNP,
#  NNP -> KANTOR,
#  KANTOR -> 'BERITA',
#  NNP -> 'AFP',
#  Z -> '.',
#  S -> PP NP-SBJ VP Z,
#  PP -> IN NP,
#  IN -> 'SELAMA',
#  NP -> CD,
#  CD -> 'BERTAHUN-TAHUN',
#  NP-SBJ -> NN,
#  NN -> 'MONYET',
#  VP -> VB NP,
#  VB -> 'MENGGANGGU',
#  NP -> NN NNP,
#  NN -> 'WARGA',
#  NNP -> 'DELHI',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> NN PR,
#  NN -> 'BINATANG',
#  PR -> 'INI',
#  VP -> VP CC VP,
#  VP -> VB NP,
#  VB -> 'MENAIKI',
#  NP -> NN NN,
#  NN -> 'KERETA',
#  NN -> 'METRO',
#  CC -> 'DAN',
#  VP -> ADVP VB PP,
#  ADVP -> RB,
#  RB -> 'BAHKAN',
#  VB -> 'BERKELIARAN',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NN NN NN,
#  NN -> 'KOMPLEKS',
#  NN -> 'GEDUNG',
#  NN -> 'PARLEMEN',
#  Z -> '.',
#  S -> ADJP NP-SBJ VP Z,
#  ADJP -> NEG JJ PR,
#  NEG -> 'BELUM',
#  JJ -> 'LAMA',
#  PR -> 'INI',
#  NP-SBJ -> NN NN,
#  NN -> 'KAWANAN',
#  NN -> 'MONYET',
#  VP -> VB NP,
#  VB -> 'MENYERBU',
#  NP -> NP CC NP,
#  NP -> NN NN,
#  NN -> 'KANTOR',
#  NN -> PERDANA,
#  PERDANA -> 'MENTERI',
#  CC -> 'DAN',
#  NP -> NN NN,
#  NN -> 'DEPARTEMEN',
#  NN -> 'PERTAHANAN',
#  Z -> '.',
#  S -> NP-SBJ-1 VP Z,
#  NP-SBJ-1 -> NN PR,
#  NN -> 'BINATANG',
#  PR -> 'INI',
#  VP -> NEG MD VP,
#  NEG -> 'TIDAK',
#  MD -> 'BISA',
#  VP -> VB NP SBAR,
#  VB -> 'DIBUNUH',
#  NP -> '*-1',
#  SBAR -> SC S,
#  SC -> 'KARENA',
#  S -> NP-SBJ VP,
#  NP-SBJ -> NN NNP,
#  NN -> 'MASYARAKAT',
#  NNP -> 'INDIA',
#  VP -> VB S,
#  VB -> 'MENGANGGAP',
#  S -> NP-SBJ ADJP-PRD,
#  NP-SBJ -> PRP,
#  PRP -> 'MEREKA',
#  ADJP-PRD -> JJ,
#  JJ -> 'SUCI',
#  Z -> '.',
#  S -> CC S-NOM Z NP-SBJ ADVP VP Z,
#  CC -> 'SELAIN',
#  S-NOM -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> MD VP,
#  MD -> 'HARUS',
#  VP -> VB NP,
#  VB -> 'MENGUSIR',
#  NP -> NN NN,
#  NN -> 'KAWANAN',
#  NN -> 'MONYET',
#  Z -> ',',
#  NP-SBJ -> NNP NNP,
#  NNP -> 'PEMKOT',
#  NNP -> 'DELHI',
#  ADVP -> RB,
#  RB -> 'JUGA',
#  VP -> VB S,
#  VB -> 'KESULITAN',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> 'MENGATASI',
#  NP -> NN NN,
#  NN -> 'WABAH',
#  NN -> DEMAM,
#  DEMAM -> 'BERDARAH',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> NP SBAR,
#  NP -> NN NN,
#  NN -> 'CURAH',
#  NN -> 'HUJAN',
#  SBAR -> SC FRAG,
#  SC -> 'YANG',
#  FRAG -> ADJP,
#  ADJP -> JJ,
#  JJ -> 'TINGGI',
#  VP -> VB NP,
#  VB -> 'MENYEBABKAN',
#  NP -> NP Z NP,
#  NP -> CD NN,
#  CD -> 'BANYAK',
#  NN -> 'GENANGAN',
#  Z -> ',',
#  NP -> NP SBAR,
#  NP -> NP PP,
#  NP -> NN JJ,
#  NN -> 'TEMPAT',
#  JJ -> 'IDEAL',
#  PP -> IN NP,
#  IN -> 'BAGI',
#  NP -> NN NNP,
#  NN -> 'NYAMUK',
#  NNP -> 'AEDES',
#  SBAR -> '0' S,
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB,
#  VB -> BERKEMBANG,
#  BERKEMBANG -> 'BIAK',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> NN,
#  NN -> 'PEMKOT',
#  VP -> MD VP,
#  MD -> 'TELAH',
#  VP -> VB NP PP SBAR,
#  VB -> 'MENEMPATKAN',
#  NP -> NN,
#  NN -> 'IKAN',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> CD NN NN,
#  CD -> 'BERBAGAI',
#  NN -> 'GENANGAN',
#  NN -> 'AIR',
#  SBAR -> SC S,
#  SC -> 'UNTUK',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> 'MEMANGSA',
#  NP -> NN NN,
#  NN -> 'TELUR',
#  NN -> 'NYAMUK',
#  Z -> '.',
#  S -> NP-SBJ VP,
#  NP-SBJ -> NN NNP,
#  NN -> 'MILIARDER',
#  NNP -> 'AS',
#  VP -> VB NP,
#  VB -> 'JAMU',
#  NP -> NN NNP,
#  NN -> ORANG,
#  ORANG -> 'KAYA',
#  NNP -> 'CINA',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> NP NP,
#  NP -> CD NN NNP,
#  CD -> 'DUA',
#  NN -> 'MILIARDER',
#  NNP -> 'AMERIKA',
#  NP -> NP CC NP,
#  NP -> NNP NNP,
#  NNP -> 'BILL',
#  NNP -> 'GATES',
#  CC -> 'DAN',
#  NP -> NNP NNP,
#  NNP -> 'WARREN',
#  NNP -> 'BUFFETT',
#  VP -> MD VP,
#  MD -> 'AKAN',
#  VP -> VB NP,
#  VB -> 'MENGADAKAN',
#  NP -> NP PP PP,
#  NP -> NN NN,
#  NN -> 'JAMUAN',
#  NN -> MAKAN,
#  MAKAN -> 'MALAM',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NNP,
#  NNP -> 'BEIJING',
#  PP -> IN NP,
#  IN -> 'BAGI',
#  NP -> NP PP,
#  NP -> CD NN JJ,
#  CD -> 'SEJUMLAH',
#  NN -> 'ORANG',
#  JJ -> 'TERKAYA',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NNP,
#  NNP -> 'CINA',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> NNP CC NNP,
#  NNP -> 'GATES',
#  CC -> 'DAN',
#  NNP -> 'BUFFETT',
#  VP -> VB SBAR,
#  VB -> 'MENGATAKAN',
#  SBAR -> '0' S,
#  S -> NP-SBJ VP,
#  NP-SBJ -> PRP,
#  PRP -> 'MEREKA',
#  VP -> VP SBAR,
#  VP -> VB PP,
#  VB -> 'BERADA',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NNP,
#  NNP -> 'CINA',
#  SBAR -> SC S,
#  SC -> 'UNTUK',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> 'MEMPELAJARI',
#  NP -> NP PP,
#  NP -> NN NN,
#  NN -> 'KEGIATAN',
#  NN -> 'AMAL',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NN PR,
#  NN -> 'NEGARA',
#  PR -> 'ITU',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> CD NN,
#  CD -> 'BANYAK',
#  NN -> 'ORANG',
#  VP -> VB SBAR,
#  VB -> 'MENDUGA',
#  SBAR -> '0' S,
#  S -> NP-SBJ ADVP VP,
#  NP-SBJ -> PRP,
#  PRP -> 'MEREKA',
#  ADVP -> RB,
#  RB -> 'INGIN',
#  VP -> VB NP SBAR,
#  VB -> 'MEMBUJUK',
#  NP -> DT NN,
#  DT -> 'PARA',
#  NN -> 'TAMU',
#  SBAR -> SC S,
#  SC -> 'AGAR',
#  S -> NP-SBJ NP-1 VP,
#  NP-SBJ -> '*',
#  NP-1 -> QP,
#  QP -> RB CD,
#  RB -> 'LEBIH',
#  CD -> 'BANYAK',
#  VP -> VB NP PP,
#  VB -> 'MENYUMBANG',
#  NP -> '*T*-1',
#  PP -> IN NP,
#  IN -> 'UNTUK',
#  NP -> NN,
#  NN -> 'AMAL',
#  Z -> '.',
#  S -> NP-SBJ-1 VP Z,
#  NP-SBJ-1 -> NP PR,
#  NP -> NP NP,
#  NP -> CD,
#  CD -> 'KEDUA',
#  NP -> NN JJ NN,
#  NN -> 'ORANG',
#  JJ -> 'TERKAYA',
#  NN -> 'DUNIA',
#  PR -> 'ITU',
#  VP -> MD VP,
#  MD -> 'SUDAH',
#  VP -> VB S,
#  VB -> 'BERHASIL',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*-1',
#  VP -> VB NP SBAR,
#  VB -> 'MEMBUJUK',
#  NP -> NP SBAR PP,
#  NP -> CD NN,
#  CD -> 'BANYAK',
#  NN -> 'ORANG',
#  SBAR -> SC FRAG,
#  SC -> 'YANG',
#  FRAG -> ADJP,
#  ADJP -> RB JJ,
#  RB -> 'SANGAT',
#  JJ -> 'KAYA',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NNP,
#  NNP -> 'AMERIKA',
#  SBAR -> SC S,
#  SC -> 'AGAR',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> 'MENYUMBANGKAN',
#  NP -> CD NN PRP,
#  CD -> 'SEPARUH',
#  NN -> 'KEKAYAAN',
#  PRP -> 'MEREKA',
#  Z -> '.',
#  S -> SINV Z S Z,
#  SINV -> VP NP-SBJ,
#  VP -> VB,
#  VB -> 'ADA',
#  NP-SBJ -> NP PP,
#  NP -> NN,
#  NN -> 'KERAHASIAAN',
#  PP -> IN NP,
#  IN -> 'MENGENAI',
#  NP -> NN PR,
#  NN -> 'ACARA',
#  PR -> 'ITU',
#  Z -> ',',
#  S -> NP-SBJ VP,
#  NP-SBJ -> NN NN,
#  NN -> 'PIHAK',
#  NN -> 'PENYELENGGARA',
#  VP -> NEG VB NP,
#  NEG -> 'TIDAK',
#  VB -> 'MEMBEBERKAN',
#  NP -> NN NN,
#  NN -> 'NAMA-NAMA',
#  NN -> 'TAMU',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> NP SBAR PR,
#  NP -> CD NN,
#  CD -> SALAH,
#  SALAH -> 'SATU',
#  NN -> 'ORANG',
#  SBAR -> SC S,
#  SC -> 'YANG',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> MD VP,
#  MD -> 'AKAN',
#  VP -> VB NP,
#  VB -> 'MENGHADIRI',
#  NP -> NN NN,
#  NN -> 'JAMUAN',
#  NN -> MAKAN,
#  MAKAN -> 'MALAM',
#  PR -> 'ITU',
#  VP -> VB NP,
#  VB -> 'ADALAH',
#  NP -> NP Z NP,
#  NP -> NNP NNP,
#  NNP -> 'CHEN',
#  NNP -> 'GUANGBIAO',
#  Z -> ',',
#  NP -> NP SBAR,
#  NP -> NND NN,
#  NND -> 'SEORANG',
#  NN -> 'MILIARDER',
#  SBAR -> SC S,
#  SC -> 'YANG',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP PP,
#  VB -> 'MERAUP',
#  NP -> NN,
#  NN -> 'KEKAYAAN',
#  PP -> IN NP,
#  IN -> 'DARI',
#  NP -> NN S-NOM,
#  NN -> 'BISNIS',
#  S-NOM -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> MENDAUR,
#  MENDAUR -> 'ULANG',
#  NP -> NP PP,
#  NP -> NN,
#  NN -> 'SAMPAH',
#  PP -> IN NP,
#  IN -> 'DARI',
#  NP -> NN NN,
#  NN -> 'INDUSTRI',
#  NN -> 'BANGUNAN',
#  Z -> '.',
#  S -> NP-SBJ VP Z,
#  NP-SBJ -> PRP,
#  PRP -> 'DIA',
#  VP -> VB PP SBAR,
#  VB -> 'MENGATAKAN',
#  PP -> IN NP,
#  IN -> 'KEPADA',
#  NP -> NNP,
#  NNP -> 'BBC',
#  SBAR -> SC S,
#  SC -> 'BAHWA',
#  S -> NP-SBJ-1 VP,
#  NP-SBJ-1 -> PRP,
#  PRP -> 'DIA',
#  VP -> MD VP,
#  MD -> 'SUDAH',
#  VP -> VB S,
#  VB -> 'BERENCANA',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*-1',
#  VP -> VB NP PP SBAR,
#  VB -> 'MENYUMBANGKAN',
#  NP -> CD NN PRP,
#  CD -> 'SELURUH',
#  NN -> 'HARTA',
#  PRP -> 'NYA',
#  PP -> IN NP,
#  IN -> 'UNTUK',
#  NP -> NN,
#  NN -> 'AMAL',
#  SBAR -> SC S,
#  SC -> 'BILA',
#  S -> NP-SBJ VP,
#  NP-SBJ -> PRP,
#  PRP -> 'DIA',
#  VP -> VB,
#  VB -> 'MENINGGAL',
#  Z -> '.',
#  S -> Z S-NOM-SBJ VP Z,
#  Z -> '"',
#  S-NOM-SBJ -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB CC VB,
#  VB -> 'BERAMAL',
#  CC -> 'DAN',
#  VB -> 'MEMBANTU',
#  VP -> MD VP,
#  MD -> 'SUDAH',
#  VP -> VB NP PP,
#  VB -> 'MENJADI',
#  NP -> NP PP,
#  NP -> NN,
#  NN -> 'BAGIAN',
#  PP -> IN NP,
#  IN -> 'DARI',
#  NP -> NN NNP,
#  NN -> 'BUDAYA',
#  NNP -> 'CINA',
#  PP -> IN NP,
#  IN -> 'SELAMA',
#  NP -> CD NN,
#  CD -> '5.000',
#  NN -> 'TAHUN',
#  Z -> '.',
#  S -> CC NP-SBJ-1 VP Z Z,
#  CC -> 'TETAPI',
#  NP-SBJ-1 -> NN NN JJ,
#  NN -> 'KEGIATAN',
#  NN -> 'AMAL',
#  JJ -> 'RESMI',
#  VP -> MD VP,
#  MD -> 'BARU',
#  VP -> VB NP PP PP Z SBAR,
#  VB -> 'DIKEMBANGKAN',
#  NP -> '*-1',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NNP,
#  NNP -> 'CINA',
#  PP -> IN NP,
#  IN -> 'DALAM',
#  NP -> CD NN JJ,
#  CD -> '30',
#  NN -> 'TAHUN',
#  JJ -> 'TERAKHIR',
#  Z -> ',',
#  SBAR -> SC S,
#  SC -> 'SEJAK',
#  S -> NP-SBJ VP,
#  NP-SBJ -> PRP,
#  PRP -> 'KAMI',
#  VP -> VB NP,
#  VB -> 'MENERAPKAN',
#  NP -> NN,
#  NN -> REFORMASI,
#  REFORMASI -> 'EKONOMI',
#  Z -> '.',
#  Z -> '"',
#  SINV -> Z S-TPC-1 Z Z VP NP-SBJ Z,
#  Z -> '"',
#  S-TPC-1 -> S CC S,
#  S -> NP-SBJ VP,
#  NP-SBJ -> CD NN,
#  CD -> 'BANYAK',
#  NN -> 'ORANG',
#  VP -> MD VP,
#  MD -> 'BARU',
#  VP -> MD VP,
#  MD -> 'MULAI',
#  VP -> VB ADJP,
#  VB -> 'MENJADI',
#  ADJP -> JJ,
#  JJ -> 'KAYA',
#  CC -> 'DAN',
#  S -> NP-SBJ ADVP VP,
#  NP-SBJ -> PRP,
#  PRP -> 'KAMI',
#  ADVP -> RB RB,
#  RB -> BARU-BARU,
#  BARU-BARU -> 'INI',
#  RB -> 'SAJA',
#  VP -> MD VP,
#  MD -> 'BISA',
#  VP -> VB NP NP,
#  VB -> 'MEMBERI',
#  NP -> NN,
#  NN -> 'MAKAN',
#  NP -> NN NN,
#  NN -> 'DIRI',
#  NN -> 'SENDIRI',
#  Z -> ',',
#  Z -> '"',
#  VP -> VB S,
#  VB -> 'KATA',
#  S -> '*T*-1',
#  NP-SBJ -> PRP,
#  PRP -> 'NYA',
#  Z -> '.',
#  S -> S-NOM-SBJ ADVP VP Z,
#  S-NOM-SBJ -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP PP,
#  VB -> 'MENYUMBANGKAN',
#  NP -> NN,
#  NN -> 'UANG',
#  PP -> IN NP,
#  IN -> 'UNTUK',
#  NP -> NN,
#  NN -> 'AMAL',
#  ADVP -> NEG RB,
#  NEG -> 'BELUM',
#  RB -> 'BEGITU',
#  VP -> VB PP ADJP,
#  VB -> 'BERKEMBANG',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> NNP,
#  NNP -> 'CINA',
#  ADJP -> JJ PP,
#  JJ -> 'SEBAIK',
#  PP -> IN NP,
#  IN -> 'DI',
#  NP -> CD NN JJ,
#  CD -> 'BANYAK',
#  NN -> 'NEGARA',
#  JJ -> 'LAIN',
#  Z -> '.',
#  S -> SBAR Z NP-SBJ VP Z,
#  SBAR -> SC S,
#  SC -> 'KALAU',
#  S -> NP-SBJ-1 VP,
#  NP-SBJ-1 -> NN NN PR,
#  NN -> 'JAMUAN',
#  NN -> MAKAN,
#  MAKAN -> 'MALAM',
#  PR -> 'INI',
#  VP -> MD VP,
#  MD -> 'BISA',
#  VP -> VB SBAR,
#  VB -> 'DIKATAKAN',
#  SBAR -> '0' S,
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*-1',
#  VP -> VB,
#  VB -> 'BERHASIL',
#  Z -> ',',
#  NP-SBJ -> NN PR,
#  NN -> 'KEBERHASILAN',
#  PR -> 'ITU',
#  VP -> VB S-PRD,
#  VB -> 'ADALAH',
#  S-PRD -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB NP,
#  VB -> 'MENDORONG',
#  NP -> NP PP,
#  NP -> NN,
#  NN -> 'PERDEBATAN',
#  PP -> IN SBAR-NOM,
#  IN -> 'MENGENAI',
#  SBAR-NOM -> SC S,
#  SC -> 'APA',
#  S -> NP-SBJ NP-PRD,
#  NP-SBJ -> '*',
#  NP-PRD -> NN S-NOM,
#  NN -> 'ARTI',
#  S-NOM -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB PP,
#  VB -> 'BERAMAL',
#  PP -> IN SBAR-NOM,
#  IN -> 'BAGI',
#  SBAR-NOM -> SC S,
#  SC -> 'YANG',
#  S -> NP-SBJ VP,
#  NP-SBJ -> '*',
#  VP -> VB,
#  VB -> 'MEMBUTUHKAN',
#  Z -> '.',
#  S -> NP-SBJ-1 VP,
#  NP-SBJ-1 -> NN NP,
#  NN -> 'KISAH',
#  NP -> NN NNP,
#  NN -> 'PENDIRI',
#  NNP -> 'FACEBOOK',
#  VP -> VB S,
#  VB -> 'DIBUAT',
#  S -> NP-SBJ NP-PRD,
#  NP-SBJ -> '*-1',
#  NP-PRD -> NN,
#  NN -> 'KOMIK',
#  S -> NP-SBJ-1 VP Z,
#  NP-SBJ-1 -> NN NP,
#  NN -> 'KISAH',
#  NP -> NP NP,
#  NP -> NN NNP,
#  NN -> 'PENDIRI',
#  NNP -> 'FACEBOOK',
#  NP -> NNP NNP,
#  NNP -> 'MARK',
#  NNP -> 'ZUCKERBERG',
#  VP -> MD VP,
#  MD -> 'AKAN',
#  VP -> VB NP PP,
#  VB -> 'DICERITAKAN',
#  NP -> '*-1',
#  PP -> IN NP,
#  IN -> 'DALAM',
#  NP -> NND NN NN,
#  NND -> 'SEBUAH',
#  NN -> 'KOMIK',
#  NN -> 'BIOGRAFI',
#  Z -> '.',
#  S -> S Z NP NP Z,
#  S -> NP-1 Z VP,
#  ...]

# %% [markdown]
# ###Print top-10 rules

# %%
#here
Counter(t).most_common(10)
# Out:
# [(PP -> IN NP, 39),
#  (S -> NP-SBJ VP, 32),
#  (Z -> '.', 31),
#  (VP -> VB NP, 24),
#  (NP-SBJ -> '*', 23),
#  (SBAR -> SC S, 20),
#  (NP -> NN, 18),
#  (VP -> MD VP, 18),
#  (IN -> 'DI', 17),
#  (NP -> NN NN, 16)]

# %% [markdown]
# ###Buat Grammar CFG

# %%
#here
grammar = CFG(Nonterminal('S'), set(t))

# %%
print(grammar)
# Out:
# Grammar with 459 productions (start state = S)
#     NN -> 'MONYET'
#     JJ -> 'PANJANG'
#     NN -> 'DUNIA'
#     RB -> 'BEGITU'
#     NNP -> 'PEMERINTAH'
#     NN -> 'ACARA'
#     VP -> VP SBAR
#     ADJP -> Z JJ Z
#     VB -> 'ADA'
#     VB -> 'MENDAPATKAN'
#     NP-SBJ -> '*'
#     NP -> NP NP
#     NP-SBJ-1 -> NN NN PR
#     VB -> 'MENCAPAI'
#     JJ -> 'KECIL'
#     NN -> 'NAMA-NAMA'
#     S-TPC-1 -> NP-SBJ-2 VP
#     NP -> NNP
#     VB -> BERKEMBANG
#     VB -> 'BERKEMBANG'
#     REFORMASI -> 'EKONOMI'
#     VB -> 'MENYUMBANG'
#     S -> NP-1 Z VP
#     NN -> REFORMASI
#     NP-SBJ -> NP NP
#     CD -> '5.000'
#     CD -> 'SEPARUH'
#     NN -> 'KEBERHASILAN'
#     VP -> VB SBAR
#     NP-SBJ -> NN NP
#     RB -> 'SERING'
#     NN -> 'GEDUNG'
#     VB -> 'KESULITAN'
#     NP-SBJ -> '*-1'
#     PR -> 'DEMIKIAN'
#     NN -> 'MONYET-MONYET'
#     VP -> VB NP
#     VP -> Z VB Z
#     NP-SBJ-1 -> NN JJ
#     NN -> 'PIHAK'
#     NNP -> 'DELHI'
#     VB -> 'MENYERBU'
#     NP -> CD NN
#     VB -> 'MEMBERI'
#     PERDANA -> 'MENTERI'
#     JJ -> 'SEBAIK'
#     SC -> 'KALAU'
#     NN -> 'PERDEBATAN'
#     NN -> 'LOMBA'
#     CD -> 'DUA'
#     NP -> CD NN PRP
#     NNP -> 'AS'
#     NN -> 'DIRI'
#     NN -> PESTA
#     VB -> 'MENJADI'
#     CD -> 'SELURUH'
#     NP-SBJ -> NN
#     NN -> 'KANTOR'
#     NP-SBJ-1 -> QP NN
#     SC -> 'BAHWA'
#     NP -> NNP NNP NNP
#     PP -> IN NP
#     NP -> NN
#     Z -> ','
#     NP-SBJ -> NNP CC NNP
#     S-PRD -> NP-SBJ VP
#     VB -> 'MENGATAKAN'
#     VB -> 'MENDUGA'
#     NP-SBJ -> NNP NNP NNP
#     NN -> 'STADION'
#     NP -> NP SBAR PP
#     ADJP-PRD -> JJ
#     CD -> '30'
#     JJ -> 'BESAR'
#     IN -> 'DARI'
#     NP -> '*-2'
#     VB -> 'MEMBANTU'
#     ADJP -> JJ PP
#     VB -> 'MEMANGSA'
#     MD -> 'HARUS'
#     VB -> 'MENYUMBANGKAN'
#     NN -> 'PENCIPTA'
#     JJ -> LUAR
#     NP -> NN S-NOM
#     JJ -> 'LAIN'
#     MENDAUR -> 'ULANG'
#     SC -> 'APA'
#     S -> SINV Z S Z
#     NN -> 'KAWANAN'
#     S -> Z S-NOM-SBJ VP Z
#     NP -> NND NN NN
#     NP-SBJ -> NNP NNP
#     NN -> SEBAGIAN
#     ADJP -> NEG JJ PR
#     PRP -> 'MEREKA'
#     NP-1 -> NP PP
#     ADJP -> JJ
#     NN -> 'KERA'
#     NN -> 'SAMPAH'
#     S-NOM-SBJ -> NP-SBJ VP
#     NP -> NN JJ
#     VP -> VB CC VB
#     NN -> 'HUJAN'
#     NN -> 'TEMPAT'
#     ADJP -> RB JJ
#     VB -> 'DIBUNUH'
#     NN -> 'NEGARA'
#     NNP -> 'BEIJING'
#     SALAH -> 'SATU'
#     VP -> VB S-PRD
#     SC -> 'YANG'
#     NN -> 'METRO'
#     S -> NP-SBJ ADJP-PRD
#     NNP -> 'GUANGBIAO'
#     S -> SBAR Z NP-SBJ VP Z
#     VB -> 'MEMBUJUK'
#     FRAG -> ADJP
#     NN -> 'SEJENIS'
#     NNP -> 'THE'
#     NN -> 'TAHUN'
#     NP -> CD NN NNP
#     NN -> 'DEPARTEMEN'
#     LUAR -> 'BIASA'
#     NN -> 'PELATIH'
#     NP -> CD NN PR
#     NN -> 'WABAH'
#     VP -> VB NP PP SBAR
#     SBAR-NOM -> SC S
#     VB -> 'ADALAH'
#     NNP -> 'PRODUCTIONS'
#     NNP -> 'CINA'
#     VB -> 'KATA'
#     VB -> 'DITEMPATKAN'
#     CC -> 'TETAPI'
#     PR -> 'ITU'
#     NP -> DT NN
#     NN -> 'PENDIRI'
#     IN -> 'MENGENAI'
#     NNP -> 'RAJASTHAN'
#     VB -> 'DIRILIS'
#     CD -> '10'
#     NP-LGS -> NN
#     JJ -> 'KHUSUS'
#     VB -> 'MELEPAS'
#     VB -> 'MENGGANGGU'
#     VB -> 'MENGUSIR'
#     NP -> NN NN
#     NN -> 'KERETA'
#     NN -> 'SERBUAN'
#     Z -> ':'
#     NN -> 'KERAHASIAAN'
#     NP-SBJ-1 -> NN PR
#     PRP -> 'DIA'
#     NN -> 'BANGUNAN'
#     NNP -> 'FACEBOOK'
#     NNP -> 'SOCIAL'
#     PRP -> 'KAMI'
#     VB -> 'BEREKOR'
#     NNP -> 'BILL'
#     S -> NP-SBJ VP Z
#     NNP -> 'BBC'
#     VB -> 'MERAUP'
#     NN -> 'NANTI'
#     JJ -> 'HITAM'
#     SINV -> Z S-TPC-1 Z Z VP NP-SBJ Z
#     VB -> 'MEMPELAJARI'
#     NNP -> 'PENERBIT'
#     CD -> 'BANYAK'
#     NNP -> 'DEVENDER'
#     VB -> 'DIANGGAP'
#     VB -> 'BERBADAN'
#     SBAR -> SC FRAG
#     IN -> 'DALAM'
#     NNP -> 'IBUKOTA'
#     SC -> 'AGAR'
#     PESTA -> 'OLAHRAGA'
#     NN -> 'TALI'
#     VB -> 'MENDORONG'
#     S -> S-NOM-SBJ ADVP VP Z
#     VB -> 'MENGATASI'
#     MAKAN -> 'MALAM'
#     CC -> 'DAN'
#     BARU-BARU -> 'INI'
#     RB -> 'INGIN'
#     VB -> 'AMANKAN'
#     CC -> 'SELAIN'
#     NNP -> 'WARREN'
#     NN -> 'CURAH'
#     JJ -> 'IDEAL'
#     KANTOR -> 'BERITA'
#     NEGARA -> 'BAGIAN'
#     NN -> 'PENYELENGGARA'
#     JJ -> 'LAMA'
#     NN -> 'WAJAH'
#     NNP -> 'AMERIKA'
#     NP -> NNP CD
#     NN -> PERDANA
#     VP -> ADVP VB PP
#     JJ -> 'UMUM'
#     JJ -> 'TINGGI'
#     UCP-PRD -> VP CC ADJP
#     VB -> 'BERAMAL'
#     NN -> 'AIR'
#     VB -> MENDAUR
#     MD -> 'AKAN'
#     NNP -> 'PRASAD'
#     NP -> NN PR
#     S -> S CC S Z
#     SINV -> VP NP-SBJ
#     CD -> '15'
#     NN -> 'LUAR'
#     IN -> 'KEPADA'
#     NNP -> 'KOTA'
#     NN -> 'MASYARAKAT'
#     VB -> 'TERSEDIA'
#     ADVP -> RB
#     NNP -> 'ZUCKERBERG'
#     NN -> 'TINJU'
#     NN -> 'INDUSTRI'
#     VP -> VB PP ADJP
#     NN -> 'JAMUAN'
#     VP -> NEG MD VP
#     CD -> SALAH
#     IN -> 'PADA'
#     FW -> 'HOCKEY'
#     JJ -> 'RESMI'
#     NP-SBJ -> NP PP
#     NNP -> 'DESEMBER'
#     S -> S Z S CC S Z
#     S -> '*T*-1'
#     NP-SBJ-1 -> NNP NNP
#     ORANG -> 'KAYA'
#     S -> S Z NP NP Z
#     NN -> 'PEMERINTAH'
#     NP-SBJ-1 -> NP PR
#     NN -> 'HARTA'
#     IN -> 'DENGAN'
#     NNP -> 'NETWORK'
#     S-NOM -> NP-SBJ VP
#     ADVP -> NEG RB
#     NP -> NN NP
#     NP -> NP PP
#     S -> NP-SBJ VP
#     MD -> 'MULAI'
#     NNP -> PESTA
#     NP -> '*-1'
#     VP -> VP CC VP
#     NN -> 'KEGIATAN'
#     DT -> 'PARA'
#     NP -> CD NN JJ
#     NNP -> 'MARK'
#     NN -> ORANG
#     NN -> 'ORANG'
#     NN -> 'TANGGAL'
#     NP -> '*T*-1'
#     NN -> 'HEWAN'
#     S -> NP-SBJ NP-PRD
#     NP-SBJ -> CD NN
#     NP-SBJ-1 -> NN NP
#     NNP -> NEGARA
#     NN -> 'JUDUL'
#     PRP -> 'NYA'
#     NP -> NND NN
#     SC -> 'SEJAK'
#     QP -> RB CD
#     VB -> 'BERWARNA'
#     NNP -> 'MAIDA'
#     VB -> 'MENDEKAT'
#     ADVP -> RB RB
#     S -> CC NP-SBJ-1 VP Z Z
#     NNP -> 'PENULIS'
#     RB -> 'JUGA'
#     CD -> 'BERTAHUN-TAHUN'
#     IN -> 'UNTUK'
#     SEBAGIAN -> 'BESAR'
#     VP -> VB NP PP PP Z SBAR
#     NN -> 'GENANGAN'
#     NNP -> 'BLUEWATER'
#     PR -> 'INI'
#     S -> NP-SBJ-1 Z ADVP VP Z
#     VB -> 'MENINGGAL'
#     IN -> 'SELAMA'
#     NP-SBJ -> NN NNP
#     SC -> 'KARENA'
#     NP-SBJ -> NP SBAR
#     PR -> 'TERSEBUT'
#     NP-SBJ-2 -> NN JJ
#     NN -> 'KANTOR-KANTOR'
#     NP -> NN NNP
#     S -> NP-SBJ ADVP VP
#     NN -> 'KOMPLEKS'
#     NP -> CD NN NN
#     VB -> 'MENDATANGKAN'
#     VB -> 'DIKATAKAN'
#     NP -> NP SBAR
#     NP-SBJ -> NP SBAR PR
#     VP -> VB NP NP
#     MD -> 'BARU'
#     NNP -> 'OKTOBER'
#     VP -> VB S
#     NN -> 'BINATANG'
#     NN -> 'BISNIS'
#     NN -> 'LAPORAN'
#     VP -> VB PP
#     NN -> 'BUDAYA'
#     Z -> '.'
#     MD -> 'SUDAH'
#     NP -> NNP NNP
#     VB -> 'MEMBUTUHKAN'
#     NNP -> KANTOR
#     VB -> 'BERHASIL'
#     VB -> 'JAMU'
#     NP-SBJ-1 -> NN NN JJ
#     VP -> MD VP
#     RB -> 'SETIDAKNYA'
#     NNP -> 'PEMKOT'
#     NN -> 'FILM'
#     NN -> 'PERNYATAAN'
#     NN -> 'WARGA'
#     NN -> 'PERTANDINGAN'
#     NP-SBJ-1 -> '*'
#     NP-SBJ -> PRP
#     S -> NP-SBJ-1 VP
#     VB -> 'DIKEMBANGKAN'
#     NN -> MAKAN
#     NN -> 'MAKAN'
#     NP -> NN NN NN
#     NP -> CD
#     VP -> VB NP NP-LGS
#     NNP -> 'CHEN'
#     CD -> 'SEJUMLAH'
#     NN -> 'PARLEMEN'
#     NP -> PRP
#     NN -> 'JENIS'
#     CD -> 'BEBERAPA'
#     VP -> VB NP SBAR
#     NN -> 'JUMLAH'
#     BERKEMBANG -> 'BIAK'
#     VB -> 'BERKELIARAN'
#     CD -> 'KEDUA'
#     NN -> 'PERTAHANAN'
#     SC -> 'UNTUK'
#     NN -> 'PEJABAT'
#     MD -> 'BISA'
#     NND -> 'SEBUAH'
#     NN -> 'PASAR'
#     VB -> 'MENYEBUT'
#     RB -> BARU-BARU
#     S -> CC S-NOM Z NP-SBJ ADVP VP Z
#     NP -> NN CC NN
#     NP -> NN JJ NN
#     VB -> 'DIIKAT'
#     NN -> 'AMAL'
#     NN -> 'MILIARDER'
#     RB -> 'BAHKAN'
#     S -> NP-SBJ UCP-PRD
#     NNP -> 'AFP'
#     VB -> 'MENYEBABKAN'
#     IN -> 'BAGI'
#     NN -> 'UANG'
#     NNP -> 'AEDES'
#     VP -> VB PP SBAR
#     NND -> 'SEORANG'
#     IN -> 'DI'
#     VB -> 'MENGAGUMKAN'
#     S-TPC-1 -> S CC S
#     CD -> '2010'
#     NN -> 'TELUR'
#     S -> ADJP NP-SBJ VP Z
#     NN -> 'PEMKOT'
#     VB -> 'MENERAPKAN'
#     RB -> 'LEBIH'
#     NP-SBJ -> NN NN
#     NN -> 'TAMU'
#     VP -> VP Z VP Z CC VP
#     NP -> PR
#     S -> NP-SBJ NP-1 VP
#     RB -> 'SANGAT'
#     VB -> 'MENAIKI'
#     JJ -> 'TERKAYA'
#     NP -> FW
#     NN -> 'KISAH'
#     MD -> 'TELAH'
#     JJ -> 'TERAKHIR'
#     VP -> VB ADJP
#     VB -> 'MENEMPATKAN'
#     VB -> 'MENGAWASI'
#     NN -> 'KETERTIBAN'
#     NNP -> 'PERSEMAKMURAN'
#     NP -> NP PP PP
#     SINV -> Z S-TPC-1 Z Z VP NP-SBJ PP Z
#     NP-SBJ -> NN SBAR
#     NN -> 'IKAN'
#     VB -> 'MENGADAKAN'
#     FRAG -> NP
#     VP -> VB NP PP
#     PP -> IN SBAR-NOM
#     NNP -> 'INDIA'
#     NN -> 'SENDIRI'
#     NP-TTL -> NP Z NP
#     NP-SBJ-1 -> NP PP PP
#     NN -> 'KOMIK'
#     NN -> 'ARENA'
#     NP-SBJ -> NN JJ JJ
#     S -> NP-SBJ-1 ADVP VP
#     JJ -> 'SUCI'
#     NP -> NN SBAR
#     S -> PP NP-SBJ VP Z
#     NP -> NN NP-TTL
#     VB -> 'DICERITAKAN'
#     SC -> 'SEBELUM'
#     VB -> 'MENGHADIRI'
#     NN -> 'ARTI'
#     NNP -> 'GATES'
#     SBAR -> SC S
#     NP-1 -> QP
#     NP-SBJ -> NP Z NP
#     NN -> 'PERHATIAN'
#     SC -> 'BEGITU'
#     DEMAM -> 'BERDARAH'
#     NN -> 'KEKAYAAN'
#     NN -> 'NYAMUK'
#     NN -> 'BIOGRAFI'
#     NP -> NP CC NP
#     NN -> DEMAM
#     NP -> NP Z NP
#     VB -> 'BERENCANA'
#     NNP -> 'BUFFETT'
#     JJ -> 'KAYA'
#     VP -> NEG VB NP
#     NNP -> 'JEROME'
#     VB -> 'MEMILIKI'
#     S -> NP-SBJ-1 VP Z
#     NN -> 'BAGIAN'
#     CD -> 'BERBAGAI'
#     VB -> 'MEMBEBERKAN'
#     NP-TTL -> NNP NNP NNP
#     VB -> 'MENGERAHKAN'
#     VB -> 'BERADA'
#     SC -> 'BILA'
#     NP-PRD -> NN S-NOM
#     NEG -> 'TIDAK'
#     NEG -> 'BELUM'
#     VB -> 'MENYEBUTKAN'
#     NP -> NN CD NNP NN
#     VB -> 'MELAPORKAN'
#     VB -> 'DISERBU'
#     CD -> 'RIBUAN'
#     VB -> 'DIKERAHKAN'
#     VB -> 'DIBUAT'
#     NP-SBJ-1 -> PRP
#     CD -> '28'
#     RB -> 'SAJA'
#     SBAR -> '0' S
#     NP-PRD -> NN
#     Z -> '"'
#     NP-SBJ -> NN PR
#     VP -> VB
#     VB -> 'MENGANGGAP'

# %% [markdown]
# ###Lakukan parsing pada contoh kalimat

# %%
#here

parser = BottomUpChartParser(grammar)
sentence = 'Binatang ini tidak bisa dibunuh karena masyarakat India menganggap mereka suci .'.upper().split()
parsed = list(parser.parse(sentence))
print(parsed[0])
# Out:
# (S
#   (NP-SBJ (NP (NN BINATANG)) (NP (PR INI)))
#   (VP
#     (VP (NEG TIDAK) (MD BISA) (VP (VB DIBUNUH)))
#     (SBAR
#       (SC KARENA)
#       (S
#         (NP-SBJ-1 (NN MASYARAKAT) (NP (NNP INDIA)))
#         (VP
#           (VB MENGANGGAP)
#           (S (NP-SBJ (PRP MEREKA)) (ADJP-PRD (JJ SUCI)))))))
#   (Z .))

# %% [markdown]
# ###Print top-50 Lexicon

# %%
#here

countl = Counter(tleaf)
top50 = countl.most_common(50)
top50
# Out:
# [('.', 31),
#  ('*', 25),
#  ('DI', 17),
#  ('*-1', 16),
#  ('MONYET', 15),
#  (',', 15),
#  ('DAN', 13),
#  ('"', 10),
#  ('UNTUK', 9),
#  ('YANG', 8),
#  ('AKAN', 8),
#  ('0', 7),
#  ('INI', 7),
#  ('BANYAK', 6),
#  ('CINA', 6),
#  ('ORANG', 6),
#  ('DELHI', 5),
#  ('DARI', 5),
#  ('MEREKA', 5),
#  ('AMAL', 5),
#  ('ITU', 5),
#  ('MENGUSIR', 4),
#  ('KECIL', 4),
#  ('PEMKOT', 4),
#  ('BESAR', 4),
#  ('FACEBOOK', 4),
#  ('PEMERINTAH', 3),
#  ('LAIN', 3),
#  ('INDIA', 3),
#  ('DIKERAHKAN', 3),
#  ('DENGAN', 3),
#  ('STADION', 3),
#  ('DUA', 3),
#  ('*T*-1', 3),
#  ('BISA', 3),
#  ('BAGI', 3),
#  ('MILIARDER', 3),
#  ('KAYA', 3),
#  ('JAMUAN', 3),
#  ('MALAM', 3),
#  ('SUDAH', 3),
#  ('MENYUMBANGKAN', 3),
#  ('MENGENAI', 3),
#  ('DIA', 3),
#  ('KISAH', 3),
#  ('KOMIK', 3),
#  ('ZUCKERBERG', 3),
#  ('OLAHRAGA', 2),
#  ('KOTA', 2),
#  ('MONYET-MONYET', 2)]

# %% [markdown]
# ###Buat 5 kalimat baru (manual) dari top-50 lexicon, dan Parsing

# %%
#here

sentence = ['Zuckerberg itu mengusir monyet facebook .','Pemerintah India menyumbangkan monyet Delhi .','monyet menyumbangkan facebook .','pemerintah kota Delhi berbadan monyet Cina .','pemerintah Cina banyak menyumbangkan monyet .']
# list_parser = []
for i in range(len(sentence)):
  sntnce = sentence[i].upper().split()
  parsed = list(parser.parse(sntnce))
  # list_parser.extend(parsed[0])
  print("[ Kalimat ke-",i+1,"]\n", parsed)
# Out:
# [ Kalimat ke- 1 ]
#  [Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['ZUCKERBERG'])]), Tree('NP', [Tree('PR', ['ITU'])])]), Tree('VP', [Tree('VB', ['MENGUSIR']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['FACEBOOK'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['ZUCKERBERG'])]), Tree('NP', [Tree('PR', ['ITU'])])]), Tree('VP', [Tree('VB', ['MENGUSIR']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['FACEBOOK'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['ZUCKERBERG'])]), Tree('NP', [Tree('PR', ['ITU'])])]), Tree('VP', [Tree('VB', ['MENGUSIR']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['FACEBOOK'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['ZUCKERBERG'])]), Tree('NP', [Tree('PR', ['ITU'])])]), Tree('VP', [Tree('VB', ['MENGUSIR']), Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['FACEBOOK'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ-1', [Tree('NP', [Tree('NNP', ['ZUCKERBERG'])]), Tree('PR', ['ITU'])]), Tree('VP', [Tree('VB', ['MENGUSIR']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['FACEBOOK'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ-1', [Tree('NP', [Tree('NNP', ['ZUCKERBERG'])]), Tree('PR', ['ITU'])]), Tree('VP', [Tree('VB', ['MENGUSIR']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['FACEBOOK'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ-1', [Tree('NP', [Tree('NNP', ['ZUCKERBERG'])]), Tree('PR', ['ITU'])]), Tree('VP', [Tree('VB', ['MENGUSIR']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['FACEBOOK'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ-1', [Tree('NP', [Tree('NNP', ['ZUCKERBERG'])]), Tree('PR', ['ITU'])]), Tree('VP', [Tree('VB', ['MENGUSIR']), Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['FACEBOOK'])])]), Tree('Z', ['.'])])]
# [ Kalimat ke- 2 ]
#  [Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['DELHI'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['DELHI'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['DELHI'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NNP', ['PEMERINTAH']), Tree('NNP', ['INDIA'])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NNP', ['PEMERINTAH']), Tree('NNP', ['INDIA'])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NNP', ['PEMERINTAH']), Tree('NNP', ['INDIA'])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['DELHI'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['PEMERINTAH']), Tree('NNP', ['INDIA'])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['PEMERINTAH']), Tree('NNP', ['INDIA'])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['DELHI'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['PEMERINTAH']), Tree('NNP', ['INDIA'])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['DELHI'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['INDIA'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP',  ...
# [ Kalimat ke- 3 ]
#  [Tree('S', [Tree('NP-SBJ', [Tree('NN', ['MONYET'])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NNP', ['FACEBOOK'])])]), Tree('Z', ['.'])])]
# [ Kalimat ke- 4 ]
#  [Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['KOTA'])])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['KOTA'])])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['KOTA'])])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['CINA'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['KOTA'])])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['KOTA'])])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['KOTA'])])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['CINA'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NNP', ['KOTA'])])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NNP', ['KOTA'])])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NNP', ['KOTA'])])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['CINA'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH']), Tree('NNP', ['KOTA'])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH']), Tree('NNP', ['KOTA'])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH']), Tree('NNP', ['KOTA'])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NNP', ['CINA'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH']), Tree('NNP', ['KOTA'])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NP', [Tree('NN', ['MONYET'])]), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH']), Tree('NNP', ['KOTA'])]), Tree('NP', [Tree('NNP', ['DELHI'])])]), Tree('VP', [Tree('VB', ['BERBADAN']), Tree('NP', [Tree('NN', ['MONYET']), Tree('NP', [Tree('NNP', ['CINA'])])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tre ...
# [ Kalimat ke- 5 ]
#  [Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['CINA'])])]), Tree('NP', [Tree('CD', ['BANYAK'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['CINA'])])]), Tree('NP', [Tree('CD', ['BANYAK'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NNP', ['CINA'])])]), Tree('NP', [Tree('CD', ['BANYAK'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH']), Tree('NNP', ['CINA'])]), Tree('NP', [Tree('CD', ['BANYAK'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH']), Tree('NNP', ['CINA'])]), Tree('NP', [Tree('CD', ['BANYAK'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NP', [Tree('NNP', ['CINA'])]), Tree('NP', [Tree('CD', ['BANYAK'])])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NP', [Tree('NNP', ['CINA'])]), Tree('NP', [Tree('CD', ['BANYAK'])])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NN', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['CINA']), Tree('CD', ['BANYAK'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['PEMERINTAH'])]), Tree('NP', [Tree('NNP', ['CINA']), Tree('CD', ['BANYAK'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NP', [Tree('NNP', ['CINA'])]), Tree('NP', [Tree('CD', ['BANYAK'])])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NNP', ['CINA']), Tree('CD', ['BANYAK'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ-1', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NP', [Tree('NNP', ['CINA'])]), Tree('NP', [Tree('CD', ['BANYAK'])])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])]), Tree('S', [Tree('NP-SBJ-1', [Tree('NN', ['PEMERINTAH']), Tree('NP', [Tree('NNP', ['CINA']), Tree('CD', ['BANYAK'])])]), Tree('VP', [Tree('VB', ['MENYUMBANGKAN']), Tree('NP', [Tree('NN', ['MONYET'])])]), Tree('Z', ['.'])])]

# %% [markdown]
# ###Selamat Mengerjakan
